# %%
from pyquibbler import iquib, override_all, q
override_all() # override numpy to work with quibs
import matplotlib.pyplot as plt
from matplotlib.widgets import RectangleSelector
import numpy as np
import os
# %matplotlib tk

# %%
# Show image:
plt.figure()
ax = plt.gca()
ax.axis([0,10,0,10])
x = iquib(2.)
y = iquib(6.)
plt.plot(x,y,'ok',markersize=16, markerfacecolor='k',picker=True)
ax.cla()
plt.plot(x,y,'or',markersize=16, markerfacecolor='r',picker=True)
# Out:
# plot(AxesSubplot(0.125,0.11;0.775x0.77), 2.0, 6.0, ok, scalex=True, scaley=True, markersize=16, markerfacecolor=k, picker=True)

# %%
# Out:
# plot(AxesSubplot(0.125,0.11;0.775x0.77), 2.0, 6.0, or, scalex=True, scaley=True, markersize=16, markerfacecolor=r, picker=True)
# Traceback (most recent call last):
#   File "/Users/roeekishony/.conda/envs/pyquibbler/lib/python3.9/site-packages/matplotlib/cbook/__init__.py", line 270, in process
#     func(*args, **kwargs)
#   File "/Users/roeekishony/Git/pyquibbler/pyquibbler/quib/graphics/event_handling/canvas_event_handler.py", line 82, in _handle_motion_notify
#     self._inverse_assign_graphics(self.current_pick_event.artist, mouse_event)
#   File "/Users/roeekishony/Git/pyquibbler/pyquibbler/quib/graphics/event_handling/canvas_event_handler.py", line 56, in _inverse_assign_graphics
#     graphics_inverse_assigner.inverse_assign_drawing_func(drawing_func=drawing_func,
#   File "/Users/roeekishony/Git/pyquibbler/pyquibbler/quib/graphics/event_handling/graphics_inverse_assigner.py", line 41, in inverse_assign_drawing_func
#     override_groups.apply()
# ...

# %%
# Define and plot a rectangle Region of Interest (ROI)
ROI = iquib(np.array([249, 344, 363, 463])); # <-- input: xmin, xmax, ymin, ymax
RectangleSelector(ax, extents=ROI, rectprops=dict(edgecolor='w', alpha=0.7, fill=False, linewidth=3));
